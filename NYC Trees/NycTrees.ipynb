# %%
import argparse
import pandas as pd
from sodapy import Socrata
import csv
import numpy as np

# %%
df = pd.read_csv('data_100000.csv')

# %%
df.head()

# df.shape
# df.info
# Out:
#    created_at  tree_id  block_id  \
# 0  08/27/2015   180683    348711
# 1  09/03/2015   200540    315986
# 2  09/05/2015   204026    218365
# 3  09/05/2015   204337    217969
# 4  08/30/2015   189565    223043
#
#                                         the_geom  tree_dbh  stump_diam  \
# 0  POINT (-73.84421521958048 40.723091773924274)         3           0
# 1   POINT (-73.81867945834878 40.79411066708779)        21           0
# 2  POINT (-73.93660770459083 40.717580740099116)         3           0
# 3  POINT (-73.93445615919741 40.713537494833226)        10           0
# 4   POINT (-73.97597938483258 40.66677775537875)        21           0
#
#   curb_loc status health                           spc_latin  ... st_assem  \
# 0   OnCurb  Alive   Fair                         Acer rubrum  ...       28
# 1   OnCurb  Alive   Fair                   Quercus palustris  ...       27
# 2   OnCurb  Alive   Good  Gleditsia triacanthos var. inermis  ...       50
# ...

# %%
df.describe()
# Out:
#              tree_id       block_id       tree_dbh     stump_diam  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean   233739.450830  289398.957140      11.261710       0.472710
# std     42482.723266  122324.350099       8.544646       3.457305
# min         7.000000  100002.000000       0.000000       0.000000
# 25%    208734.750000  212550.000000       5.000000       0.000000
# 50%    235822.500000  305825.000000      10.000000       0.000000
# 75%    264692.250000  347898.500000      16.000000       0.000000
# max    318496.000000  516315.000000     425.000000     140.000000
#
#              zipcode         cb_num       borocode       cncldist  \
# count  100000.000000  100000.000000  100000.000000  100000.000000
# mean    10824.773880     316.044520       3.083830      27.337490
# std       835.683247     125.875538       1.264942      15.184746
# min        83.000000     101.000000       1.000000       1.000000
# ...

# %%
print("There are {} rows of data".format(len(df)))
# Out:
# There are 100000 rows of data

# %%
df.isnull()
df.isnull().sum()
# Out:
# created_at       0
# tree_id          0
# block_id         0
# the_geom         0
# tree_dbh         0
# stump_diam       0
# curb_loc         0
# status           0
# health        4993
# spc_latin     4992
# spc_common    4992
# steward       4992
# guards        4992
# sidewalk      4992
# user_type        0
# problems      4992
# root_stone       0
# root_grate       0
# root_other       0
# trnk_wire        0
# trnk_light       0
# trnk_other       0
# brnch_ligh       0
# brnch_shoe       0
# brnch_othe       0
# address          0
# zipcode          0
# zip_city         0
# cb_num           0
# borocode         0
# boroname         0
# cncldist         0
# st_assem         0
# st_senate        0
# nta              0
# nta_name         0
# boro_ct          0
# state            0
# latitude         0
# longitude        0
# x_sp             0
# y_sp             0
# dtype: int64

# %%
# dropped_columns = df[['spc_latin', 'spc_common' , 'steward', 'guards', 'sidewalk', 'problems']]
# dropped_columns.head(20)
# Out:
#                              spc_latin        spc_common steward   guards  \
# 0                          Acer rubrum         red maple    None     None
# 1                    Quercus palustris           pin oak    None     None
# 2   Gleditsia triacanthos var. inermis       honeylocust    1or2     None
# 3   Gleditsia triacanthos var. inermis       honeylocust    None     None
# 4                      Tilia americana   American linden    None     None
# 5   Gleditsia triacanthos var. inermis       honeylocust    1or2  Helpful
# 6   Gleditsia triacanthos var. inermis       honeylocust    1or2  Helpful
# 7                      Tilia americana   American linden    None     None
# 8   Gleditsia triacanthos var. inermis       honeylocust    None     None
# 9                Platanus x acerifolia  London planetree    None     None
# 10               Platanus x acerifolia  London planetree    None     None
# 11               Platanus x acerifolia  London planetree    None     None
# ...

# %%
df['health'].fillna("unknown",inplace=True)
df['problems'].fillna("not_reported",inplace=True)

# df.drop(columns=['spc_latin', 'spc_common', 'steward', 'guards', 'sidewalk'], inplace=True)
# df.dropna(axis=1)
df.isnull().sum()
# Out:
# created_at    0
# tree_id       0
# block_id      0
# the_geom      0
# tree_dbh      0
# stump_diam    0
# curb_loc      0
# status        0
# health        0
# user_type     0
# problems      0
# root_stone    0
# root_grate    0
# root_other    0
# trnk_wire     0
# trnk_light    0
# trnk_other    0
# brnch_ligh    0
# brnch_shoe    0
# brnch_othe    0
# address       0
# zipcode       0
# zip_city      0
# cb_num        0
# borocode      0
# boroname      0
# cncldist      0
# st_assem      0
# st_senate     0
# nta           0
# nta_name      0
# boro_ct       0
# state         0
# latitude      0
# longitude     0
# x_sp          0
# y_sp          0
# dtype: int64

# %%
print(df.dtypes)
# Out:
# created_at     object
# tree_id         int64
# block_id        int64
# the_geom       object
# tree_dbh        int64
# stump_diam      int64
# curb_loc       object
# status         object
# user_type      object
# root_stone     object
# root_grate     object
# root_other     object
# trnk_wire      object
# trnk_light     object
# trnk_other     object
# brnch_ligh     object
# brnch_shoe     object
# brnch_othe     object
# address        object
# zipcode         int64
# zip_city       object
# cb_num          int64
# borocode        int64
# boroname       object
# cncldist        int64
# st_assem        int64
# st_senate       int64
# nta            object
# nta_name       object
# boro_ct         int64
# state          object
# latitude      float64
# longitude     float64
# x_sp          float64
# y_sp          float64
# dtype: object

# %%
df.apply(pd.Series.value_counts)
# df.value_counts(dropna=false)
# Out:
#                     created_at  tree_id  block_id  the_geom  tree_dbh  \
# -74.25438541               NaN      NaN       NaN       NaN       NaN
# -74.25418296               NaN      NaN       NaN       NaN       NaN
# -74.25409024               NaN      NaN       NaN       NaN       NaN
# -74.25391997               NaN      NaN       NaN       NaN       NaN
# -74.25388382               NaN      NaN       NaN       NaN       NaN
# ...                        ...      ...       ...       ...       ...
# Woodhaven                  NaN      NaN       NaN       NaN       NaN
# Woodlawn-Wakefield         NaN      NaN       NaN       NaN       NaN
# Woodside                   NaN      NaN       NaN       NaN       NaN
# Yes                        NaN      NaN       NaN       NaN       NaN
# Yorkville                  NaN      NaN       NaN       NaN       NaN
#
#                     stump_diam  curb_loc  status  user_type  root_stone  ...  \
# ...
